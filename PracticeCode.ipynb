# %% [markdown]
# ## Seaborn Practice

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Loading Data

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df = sns.load_dataset('car_crashes')
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
tips_df = sns.load_dataset('tips')
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights_df = sns.load_dataset('flights')
flights_df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris_df = sns.load_dataset('iris')
#iris_df.pop('species')
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
att

# %% [markdown]
# ### Distribution Plot

# %%
sns.displot(df['not_distracted'], kde=True, bins=25 ) #kde=False to remove the kernal density estimation line

# %% [markdown]
# ### Joint Plot

# %%
sns.jointplot(x='speeding',y='alcohol', data=df, kind='reg')

# %% [markdown]
# ### Hexagon Distribution

# %%
sns.jointplot(x='speeding',y='alcohol', data=df, kind='hex')

# %%
sns.jointplot(x='speeding',y='ins_premium', data=df, kind='hex')

# %% [markdown]
# ### KDE Plot

# %%
sns.kdeplot(df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# ### Pair plot

# %%
sns.pairplot(df,hue='abbrev',palette="Blues")

# %% [markdown]
# ### Rug Plot

# %%
sns.rugplot(tips_df['tip'])
# Out:
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
# ### Styling

# %%
sns.set_style('ticks')
plt.figure(figsize=(8,4))
sns.set_context('paper', font_scale=1.4)
sns.jointplot(x='speeding', y='alcohol', data=df, kind='reg')

# %% [markdown]
# ### Bar Plot

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ### Box Plot

# %%
sns.boxplot(x='day',y='total_bill', data=tips_df, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Violin Plot

# %%
sns.violinplot(x='day',y='total_bill', data=tips_df, hue='sex', split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Strip Plot

# %%
plt.figure(figsize=(8,5))
sns.stripplot(x='day', y='total_bill', data = tips_df, jitter= True, hue= 'sex', dodge=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Swarm Plot

# %%
custom_palette = {'Male': 'darkblue', 'Female': 'yellow'}
plt.figure(figsize=(8, 6), facecolor='lightgray')
sns.violinplot(x='day',y='total_bill', data=tips_df, hue='sex', split=True)
sns.swarmplot(x='day',y='total_bill', data=tips_df, hue='sex', palette=custom_palette)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Palettes

# %%
plt.figure(figsize=(8,6))
sns.set_style('darkgrid') #styles = ["white", "dark", "whitegrid", "darkgrid", "ticks"]
sns.set_context('talk')
custom_palette = {'Male': 'darkblue', 'Female': 'brown'}
sns.stripplot(x='day', y='total_bill', data = tips_df, jitter= True, hue= 'sex', dodge=True, palette=custom_palette) #palette='magma',afmhot etc builtin
plt.legend(loc=0, prop={'size': 8})

# %% [markdown]
# ### Matrix Plots

# %% [markdown]
# #### Heat Maps

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)
crash_mx = df.corr()
sns.heatmap(crash_mx, annot = True, cmap= 'Blues')
# Out:
# <AxesSubplot:>

# %%
flights_df = flights_df.pivot_table(index='month', columns='year',values='passengers')
flights_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(flights_df, cmap= 'Blues', linecolor='black', linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# ### Pair Grid

# %%
iris_g = sns.PairGrid(iris_df, hue='species')
#iris_g.map(plt.scatter)
iris_g.map_diag(plt.hist)
#iris_g.map_offdiag(plt.scatter)
iris_g.map_upper(plt.scatter)
iris_g.map_lower(sns.kdeplot)

# %%
iris_g2 = sns.PairGrid(iris_df, hue='species',
                      x_vars=["sepal_length", "sepal_width"],
                      y_vars=["petal_length", "petal_width"]
                      )
iris_g2.map(plt.scatter)
iris_g2.add_legend()

# %% [markdown]
# ### Facet Grid

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', row='smoker')
tips_fg.map(plt.hist, 'total_bill', bins=8)

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', row='smoker')
tips_fg.map(plt.scatter, 'total_bill', 'tip')

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', hue='smoker', height=4, aspect=1,
                       col_order=['Dinner', 'Lunch'], palette='Set1')
tips_fg.map(plt.scatter, 'total_bill', 'tip', edgecolor='w')

# %%
kws = dict(s=50, linewidth=0.5, edgecolor='w')
tips_fg = sns.FacetGrid(tips_df, col='sex', hue='smoker', height=4, aspect=1,
                       hue_order= ['Yes', 'No'],
                       hue_kws = dict(marker=['^','v']))
tips_fg.map(plt.scatter, 'total_bill', 'tip', **kws)
